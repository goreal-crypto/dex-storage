# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
results ={
  'mean': [
         8398,  34983.22,  60817.96,
     94816.56,  119498.1, 152389.64,
    184932.56, 212150.42, 247928.76,
    273643.32, 315168.58, 347235.96,
    375392.92, 410629.48, 439379.56,
     471780.9, 504329.26, 534017.78,
    569858.16, 600667.08,  647667.3,
    687467.76, 708043.56, 737182.02,
    772073.34,  807926.1,  839243.6,
    867975.58,  898821.7, 931979.72
  ],
  'variance': [
                     0,  3520416.811600002,
         13264039.0384, 15819516.006399991,
     47486391.21000001,  42324347.75040001,
     59927431.32639998,  81895266.36360003,
         71950344.3824, 139366409.97759998,
         70520506.0036,     110972586.0784,
    104522107.79360004, 102987009.88959998,
         98830849.1264, 119861114.00999998,
    177959598.11239997, 144304354.69159997,
    204467557.33440003, 241754700.11360005,
    247299890.48999995, 154724893.74240002,
        284787435.8864, 259740411.61960012,
     317647519.0644001, 272787088.29000014,
          374354633.56,  294431746.9636001,
    235026229.65000004,     279692665.8816
  ]
}

# %%
results = {
    'mean': [
        7892, 27060.88, 44641.28, 70996.04,
        89023.54, 107803.19, 133940.56, 151760.1,
        178620.11, 197593.72
    ],
    'variance': [
        0, 2507129.565599996, 8243089.741599998, 10618202.2184,
        14121381.3884, 20083046.573900003, 24413497.806399994,
        28922743.710000005, 25716020.0979, 34116059.9816
    ]
}

# %%
std_dev = np.sqrt(results['variance'])
ticks_count = np.arange(1, len(results['mean']) + 1)
plt.figure(figsize=(12, 6))
plt.plot(ticks_count, results['mean'], 'b-', label='Средний газ', linewidth=2, marker='o')

plt.fill_between(ticks_count, 
                 np.array(results['mean']) - std_dev,
                 np.array(results['mean']) + std_dev,
                 color='blue', alpha=0.2, label='±1 стандартное отклонение')

plt.xlabel('Количество тиков', fontsize=12)
plt.ylabel('Газ (gas units)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)
plt.xticks(ticks_count) 
plt.tight_layout()

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.plot(ticks_count, results['mean'], 'b-', label='Средний газ', linewidth=2, marker='o')
ax1.set_xlabel('Количество тиков')
ax1.set_ylabel('Газ (gas units)', color='b')
ax1.tick_params(axis='y', labelcolor='b')
ax1.grid(True, linestyle='--', alpha=0.7)

ax2 = ax1.twinx()
ax2.plot(ticks_count, results['variance'], 'r--', label='Дисперсия', linewidth=1, marker='x')
ax2.set_ylabel('Дисперсия', color='r')
ax2.tick_params(axis='y', labelcolor='r')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.title('Зависимость газа и дисперсии от количества тиков')
plt.xticks(ticks_count)
plt.tight_layout()
plt.show()

# %%
virt = [
  8398,
  38353,
  47075,
  55910,
  64654,
  73514,
  82333,
  91172,
  99881,
  108710,
  117560,
  126585,
  135258,
  144277,
  153038,
  162129,
  170523,
  179358,
  188121,
  197059,
  205800,
  214701,
  223716,
  232627,
  241240,
  250203,
  259094,
  268098,
  276843,
  285841
]

# %%
ticks_count = np.arange(1, len(virt) + 1)
plt.figure(figsize=(12, 6))
plt.plot(ticks_count, virt, 'b-', label='Средний газ', linewidth=2, marker='o')


plt.xlabel('Количество виртуальных тиков', fontsize=12)
plt.ylabel('Газ (gas units)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)
plt.xticks(ticks_count) 
plt.tight_layout()

plt.show()

# %%
data = {
    "1": [1011829, 1023349, 1034869, 1046389, 1057909, 1069429, 1080949, 1092469, 1103989, 1115509, 1127029, 1138549, 1150069, 1161589, 1173109, 1184629, 1196149, 1207669, 1219189, 1230709, 1242229, 1253749, 1265269, 1276789, 1288309, 1299829, 1311349, 1322869, 1334389, 1345909],
    "3": [533137, 544657, 556177, 567697, 579217, 590737, 602257, 613777, 625297, 636817, 648337, 659857, 671377, 682897, 694417, 705937, 717457, 728977, 740497, 752017, 763537, 775057, 786577, 798097, 809617, 821137, 832657, 844177, 855697, 867217],
    "5": [333363, 344883, 356403, 367923, 379443, 390963, 402483, 414003, 425523, 437043, 448563, 460083, 471603, 483123, 494643, 506163, 517683, 529203, 540723, 552243, 563763, 575283, 586803, 598323, 609843, 621363, 632883, 644403, 655923, 667443],
    "10": [184028, 195548, 207068, 218588, 230108, 241628, 253148, 264668, 276188, 287708, 299228, 310748, 322268, 333788, 345308, 356828, 368348, 379868, 391388, 402908, 414428, 425948, 437468, 448988, 460508, 472028, 483548, 495068, 506588, 518108],
    "50": [66183, 77703, 89223, 100743, 112263, 123783, 135303, 146823, 158343, 169863, 181383, 192903, 204423, 215943, 227463, 238983, 250503, 262023, 273543, 285063, 296583, 308103, 319623, 331143, 342663, 354183, 365703, 377223, 388743, 400263],
    "100": [49775, 61295, 72815, 84335, 95855, 107375, 118895, 130415, 141935, 153455, 164975, 176495, 188015, 199535, 211055, 222575, 234095, 245615, 257135, 268655, 280175, 291695, 303215, 314735, 326255, 337775, 349295, 360815, 372335, 383855]
}

plt.figure(figsize=(12, 8))

x = list(range(1, 31))

for spacing, values in data.items():
    plt.plot(x, values, label=f'{spacing}', linewidth=2)

plt.xlabel('Количество пересеченных тиков', fontsize=12)
plt.ylabel('Газ (gas units)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='tickSpacing', fontsize=10, title_fontsize=12)
plt.xticks(np.arange(1, 31, 1))  
plt.xlim(1, 30)
plt.ylim(0, max(data["1"]) * 1.1)

plt.tight_layout()
plt.show()
