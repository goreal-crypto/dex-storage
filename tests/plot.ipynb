# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
results = {
    'mean': [
         7892,  26965.05,  45007.27,   70890.94,
     89111.73, 107131.12, 133006.55,  151863.58,
    178187.85, 197963.67, 216950.28,  243338.77,
    262010.57, 286563.78, 306323.68,  325658.52,
    350682.78, 368865.81, 395364.94,  412258.92,
    435896.18, 463829.49, 480283.78,  498188.34,
    524926.11, 543325.75, 569866.66,  587664.25,
    605040.58, 634377.13,    653257,  679067.79,
    696924.48, 712712.62, 743662.79,  762959.59,
     786516.9, 808641.93, 826819.27,  856095.83,
    872528.71, 904228.76, 921402.64,  938854.51,
    966271.67, 980395.07, 995519.79, 1000032.91,
      1000309,   1000309
  ],
    'variance': [
                     0, 3302917.3875000007,  5435365.697100005,
         14376705.7164, 13403772.057100007,  24151999.72559999,
    30433062.947500005, 32050923.963599976,      37806291.3475,
    29175125.501099996, 33329066.261600003,  49972075.11710001,
     42345718.60509999,  61208936.87160001,  51357907.29760002,
         45422562.1896,  67300424.19160002,      80597255.7939,
     96523882.79640003,      80816033.0536, 55971402.787599996,
         85091497.9299,  82909858.07160002,  93031547.02440001,
    103179739.97789998,     120448046.2275, 115907589.44440001,
        116512356.1075, 151250969.72359994, 108620225.97309996,
          149440613.56,     145737926.9459, 131166560.54959993,
    182251966.75559995, 168522077.14589995, 160570148.60190004,
     184911506.0300001, 123330662.32509995, 163384957.49710003,
    127387048.02109998, 160280195.68590003, 166168335.04239997,
    221050314.97040004, 206264800.40989995,  199249764.3211001,
        242561539.8651,      68207073.1459, 2452906.9018999985,
                     0,                  0
  ]
}

# %%
results = {
    'mean': [
        7892, 27060.88, 44641.28, 70996.04,
        89023.54, 107803.19, 133940.56, 151760.1,
        178620.11, 197593.72
    ],
    'variance': [
        0, 2507129.565599996, 8243089.741599998, 10618202.2184,
        14121381.3884, 20083046.573900003, 24413497.806399994,
        28922743.710000005, 25716020.0979, 34116059.9816
    ]
}

# %%
std_dev = np.sqrt(results['variance'])
ticks_count = np.arange(1, len(results['mean']) + 1)
plt.figure(figsize=(12, 6))
plt.plot(ticks_count, results['mean'], 'b-', label='Средний газ', linewidth=2, marker='o')

plt.fill_between(ticks_count, 
                 np.array(results['mean']) - std_dev,
                 np.array(results['mean']) + std_dev,
                 color='blue', alpha=0.2, label='±1 стандартное отклонение')

plt.title('Зависимость газовых затрат от количества тиков', fontsize=14)
plt.xlabel('Количество тиков', fontsize=12)
plt.ylabel('Газ (gas units)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)
plt.xticks(ticks_count) 
plt.tight_layout()

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.plot(ticks_count, results['mean'], 'b-', label='Средний газ', linewidth=2, marker='o')
ax1.set_xlabel('Количество тиков')
ax1.set_ylabel('Газ (gas units)', color='b')
ax1.tick_params(axis='y', labelcolor='b')
ax1.grid(True, linestyle='--', alpha=0.7)

ax2 = ax1.twinx()
ax2.plot(ticks_count, results['variance'], 'r--', label='Дисперсия', linewidth=1, marker='x')
ax2.set_ylabel('Дисперсия', color='r')
ax2.tick_params(axis='y', labelcolor='r')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.title('Зависимость газа и дисперсии от количества тиков')
plt.xticks(ticks_count)
plt.tight_layout()
plt.show()
